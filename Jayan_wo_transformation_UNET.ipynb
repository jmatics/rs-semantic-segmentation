# %% [markdown]
# # Multiclass semantic segmentation with U-Net

# %% [markdown]
# ## 1.0 Import libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
import torch
from torch import nn
from torchgeo.samplers import RandomGeoSampler
from torch.utils.data import DataLoader
from torchgeo.datasets import stack_samples
from torchgeo.datasets import RasterDataset
from torchsummary import summary
#import pylab as plt
# torch.cuda.is_available()

# %% [markdown]
# ## 2.0 Check CUDA availability

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', DEVICE)
print()
# Out:
# Using device: cuda

# %%
#Additional Info when using cuda
if DEVICE.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# NVIDIA GeForce RTX 2060 SUPER
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %% [markdown]
# ## 3.0 Load and prepare dataset

# %%
# Create CLASS for images and labels
class BengaluruDatasetImages(RasterDataset):
    """
    Load image data that ends in *.tif
    """
    filename_glob = "*.tif"
    

class BengaluruDatasetLabels(RasterDataset):
    """
    Load label data that ends in *.tif
    """
    is_image = False
    filename_glob = "*.tif"

# %%
# base path of the dataset
TRAIN_PATH = os.path.join("Data", "Train")
VALID_PATH = os.path.join("Data", "Valid")
TEST_PATH = os.path.join("Data", "Test")
#tr_labels = lambda x: x[:,0,:,:].long()

# %%
# Create CLASS for image and label transformation

class TransformBengaluruImages(nn.Module):
    """
    Apply Min and Max scale to the image
    """

    def __init__(self):
        super().__init__()

    def forward(self, inputs):
        #inputs["image"] -= inputs["image"].min()
        #inputs["image"] /= inputs["image"].max()
        
        return inputs
    
class TransformBengaluruLabels(nn.Module):
    """
    Create additional dimensions for the labels np arrays
    """

    def __init__(self):
        super().__init__()

    def forward(self, inputs):
        # Batch
        if inputs["mask"].ndim == 4:
            inputs["mask"] = (inputs["mask"][:,0,:,:]).long()
        # Sample
        else:
            inputs["mask"] = (inputs["mask"][0,:,:]).long()
        
        return inputs

# %%
# Create Train and Test datasets
tr_im = BengaluruDatasetImages(os.path.join(TRAIN_PATH, "Images"), transforms=TransformBengaluruImages())
tr_la = BengaluruDatasetLabels(os.path.join(TRAIN_PATH, "Labels"), transforms=TransformBengaluruLabels())

TRAIN_DS = tr_im & tr_la

# Create Train and Test datasets
vl_im = BengaluruDatasetImages(os.path.join(VALID_PATH, "Images"), transforms=TransformBengaluruImages())
vl_la = BengaluruDatasetLabels(os.path.join(VALID_PATH, "Labels"), transforms=TransformBengaluruLabels())

VALID_DS = vl_im & vl_la

ts_im = BengaluruDatasetImages(os.path.join(TEST_PATH, "Images"), transforms=TransformBengaluruImages())
ts_la = BengaluruDatasetLabels(os.path.join(TEST_PATH, "Labels"), transforms=TransformBengaluruLabels())

TEST_DS = ts_im & ts_la

# %%
# Define dataset, batch, and image sizes
DATASET_SIZE = 512
BATCH_SIZE = 64
IMG_SIZE = 128

# %%
train_sampler = RandomGeoSampler(TRAIN_DS, size=IMG_SIZE, length=DATASET_SIZE)
valid_sampler = RandomGeoSampler(VALID_DS, size=IMG_SIZE, length=72)
test_sampler = RandomGeoSampler(TEST_DS, size=IMG_SIZE, length=72)

train_dl = DataLoader(TRAIN_DS, BATCH_SIZE, sampler=train_sampler, collate_fn=stack_samples)
valid_dl = DataLoader(VALID_DS, BATCH_SIZE, sampler=valid_sampler, collate_fn=stack_samples)
test_dl  = DataLoader(TEST_DS, 1, sampler=test_sampler, collate_fn=stack_samples)

# %%
import matplotlib as mpl
cmap_custom = (mpl.colors.ListedColormap(['slategray', 'sandybrown', 'greenyellow', 'forestgreen']))
        # .with_extremes(over='0.25', under='0.75'))
def visualize(image, mask):
    """PLot images in one row."""
    fig = plt.figure(figsize=(16, 8))
    #plt.imshow(image[0].transpose(0,2), vmin=0, vmax=1)
    image /= image.numpy().max()
    plt.imshow(image, cmap='gray')
    #plt.imshow(image[0])
    if mask.max()>0:
        plt.imshow(mask/3, alpha=0.6, cmap=cmap_custom, vmin=0, vmax=1, interpolation='nearest')
      
    cb = plt.colorbar(cmap=cmap_custom, ticks=np.array([0.125, 0.375, 0.625, 0.875]), boundaries=np.array([0., 0.25, 0.5, 0.75, 1]))
    # ticks=np.linspace(0.5/9, 3.5/9, 4), boundaries=np.linspace(0,4/9,5))
    cb.set_ticklabels(['Background', 'Fallow', 'Herbaceous', 'Woody'])
    plt.show()

for dl in [train_dl, valid_dl, test_dl]:
    for sample in dl:
        idx = 0
        image = sample["image"].moveaxis(1,3)[idx, :, :, 1]
        target = sample["mask"][idx, :, :]
        
        visualize(image, target)
        break

# %% [markdown]
# ## 4.0 Model definition

# %% [markdown]
# ### 4.1 UNET Class define

# %%
# Creat UNET CLASS
class UNET(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.conv1 = self.contract_block(in_channels, 32, 3, 1)
        self.conv2 = self.contract_block(32, 64, 3, 1)
        self.conv3 = self.contract_block(64, 128, 3, 1)
        self.conv4 = self.contract_block(128, 256, 3, 1)

        self.upconv4 = self.expand_block(256, 128, 3, 1)
        self.upconv3 = self.expand_block(128*2, 64, 3, 1)
        self.upconv2 = self.expand_block(64*2, 32, 3, 1)
        self.upconv1 = self.expand_block(32*2, out_channels, 3, 1)

    def __call__(self, x):

        # downsampling part
        conv1 = self.conv1(x)
        conv2 = self.conv2(conv1)
        conv3 = self.conv3(conv2)
        conv4 = self.conv4(conv3)

        upconv4 = self.upconv4(conv4)
        upconv3 = self.upconv3(torch.cat([upconv4, conv3], 1))
        upconv2 = self.upconv2(torch.cat([upconv3, conv2], 1))
        upconv1 = self.upconv1(torch.cat([upconv2, conv1], 1))

        return upconv1

    def contract_block(self, in_channels, out_channels, kernel_size, padding):

        contract = nn.Sequential(
            torch.nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, stride=1, padding=padding),
            torch.nn.BatchNorm2d(out_channels),
            torch.nn.ReLU(),
            torch.nn.Conv2d(out_channels, out_channels, kernel_size=kernel_size, stride=1, padding=padding),
            torch.nn.BatchNorm2d(out_channels),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )

        return contract

    def expand_block(self, in_channels, out_channels, kernel_size, padding):

        expand = nn.Sequential(torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding=padding),
                            torch.nn.BatchNorm2d(out_channels),
                            torch.nn.ReLU(),
                            torch.nn.Conv2d(out_channels, out_channels, kernel_size, stride=1, padding=padding),
                            torch.nn.BatchNorm2d(out_channels),
                            torch.nn.ReLU(),
                            torch.nn.ConvTranspose2d(out_channels, out_channels, kernel_size=3, stride=2, padding=1, output_padding=1) 
                            )
        return expand

# %%
# Example usage
in_channels = 5  # Number of input channels (e.g., for WV images)
out_channels = 4  # Number of output channels (e.g., number of classes)
test_model = UNET(in_channels, out_channels)
input_tensor = torch.randn(1, in_channels, 128, 128)  # Example input tensor
output_tensor = test_model(input_tensor)
print(output_tensor.shape)
# Out:
# torch.Size([1, 4, 128, 128])

# %% [markdown]
# ### 4.2 View the summary of the model

# %%
unet_model =  UNET(in_channels=5, out_channels=4).to(DEVICE)

# %% [markdown]
# ### 4.3 Define model parameters

# %%
LEARNING_RATE = 0.01
num_epochs = 100
loss_fn = nn.CrossEntropyLoss(ignore_index=255)
opt = torch.optim.Adam(unet_model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# ### 4.4 Create TRAIN function

# %%
import time
def train(model, train_dl, valid_dl, loss_fn, optimizer, acc_fn, iou_fn, epochs=1):
    start = time.time()
    model

    train_loss, valid_loss = [], []

    best_acc = 0.0

    for epoch in range(epochs):
        print('Epoch {}/{}'.format(epoch+1, epochs))
        print('-' * 10)

        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train(True)  # Set trainind mode = true
                dataloader = train_dl
            else:
                model.train(False)  # Set model to evaluate mode
                dataloader = valid_dl

            running_loss = 0.0
            running_acc = 0.0
            running_iou = 0.0

            step = 0

            # iterate over data
            for sampl in dataloader:
                x = sampl['image'].to(DEVICE)
                y = sampl['mask'].to(DEVICE)
                
                if x.isnan().any():
                    print('x nan')
                if y.isnan().any():
                    print('y nan')
                
                step += 1

                # forward pass
                if phase == 'train':
                    # zero the gradients
                    optimizer.zero_grad()
                    outputs = model(x)
                    
                    if outputs.isnan().any():
                        print('outputs nan')
                        break
                    loss = loss_fn(outputs, y)
                    

                    # the backward pass frees the graph memory, so there is no 
                    # need for torch.no_grad in this training pass
                    loss.backward()
                    optimizer.step()
                    # scheduler.step()

                else:
                    with torch.no_grad():
                        outputs = model(x)
                        loss = loss_fn(outputs, y.long())

                # stats - whatever is the phase
                acc = acc_fn(outputs, y)
                iou = iou_fn(outputs, y)

                running_acc  += acc
                running_loss += loss
                running_iou += iou
                

                if step % 20 == 0:
                    # clear_output(wait=True)
                    # print('Current step: {}  Loss: {}  Acc: {} '.format(step, loss, acc))
                    print('Current step: {};  Loss: {:.3f};  Accuracy: {:.3f}; IoU: {:.3f}; AllocMem (Mb): {:.3f}'.format(step, loss, acc, iou, torch.cuda.memory_allocated()/1024/1024))
                    # print(torch.cuda.memory_summary())
            

            epoch_loss = running_loss / step
            epoch_acc = running_acc / step
            epoch_iou = running_iou / step

            print('Phase: {}; Loss: {:.3f}; Accuracy: {:.3f}; IoU: {:.3f}'.format(phase, epoch_loss, epoch_acc, epoch_iou))

            train_loss.append(epoch_loss) if phase=='train' else valid_loss.append(epoch_loss)

    time_elapsed = time.time() - start
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))    
    
    return train_loss, valid_loss    

def acc_metric(predb, yb):
    return (predb.argmax(dim=1) == yb.to(DEVICE)).float().mean()

def iou_metric(predb, yb):
    intersection = (torch.logical_and(predb.argmax(dim=1), yb.to(DEVICE).float())).sum(()).float()
    union = (torch.logical_or(predb.argmax(dim=1), yb.to(DEVICE)).float()).sum(()).float()
    iou = (intersection + 1e-7) / (union + 1e-7)
    return iou.mean()

# %% [markdown]
# ### 4.5 Model training

# %%
train_loss, valid_loss = train(model=unet_model, 
                               train_dl=train_dl, 
                               valid_dl=valid_dl, 
                               loss_fn=loss_fn, 
                               optimizer=opt, 
                               acc_fn=acc_metric, 
                               iou_fn = iou_metric, 
                               epochs=num_epochs)
# Out:
# Epoch 1/100
# ----------
# Phase: train; Loss: 1.278; Accuracy: 0.432; IoU: 0.696
# Phase: valid; Loss: 77.605; Accuracy: 0.392; IoU: 0.709
# Epoch 2/100
# ----------
# Phase: train; Loss: 1.106; Accuracy: 0.549; IoU: 0.745
# Phase: valid; Loss: 3.262; Accuracy: 0.413; IoU: 0.613
# Epoch 3/100
# ----------
# Phase: train; Loss: 0.994; Accuracy: 0.573; IoU: 0.746
# Phase: valid; Loss: 35.565; Accuracy: 0.272; IoU: 0.539
# Epoch 4/100
# ----------
# Phase: train; Loss: 0.952; Accuracy: 0.573; IoU: 0.736
# Phase: valid; Loss: 25.129; Accuracy: 0.438; IoU: 0.727
# Epoch 5/100
# ----------
# Phase: train; Loss: 0.918; Accuracy: 0.621; IoU: 0.740
# Phase: valid; Loss: 3.976; Accuracy: 0.409; IoU: 0.705
# Epoch 6/100
# ----------
# Phase: train; Loss: 0.900; Accuracy: 0.637; IoU: 0.737
# Phase: valid; Loss: 1.512; Accuracy: 0.467; IoU: 0.722
# Epoch 7/100
# ----------
# Phase: train; Loss: 0.876; Accuracy: 0.648; IoU: 0.714
# Phase: valid; Loss: 1.215; Accuracy: 0.503; IoU: 0.725
# Epoch 8/100
# ----------
# Phase: train; Loss: 0.898; Accuracy: 0.648; IoU: 0.734
# Phase: valid; Loss: 1.239; Accuracy: 0.417; IoU: 0.575
# Epoch 9/100
# ----------
# Phase: train; Loss: 0.874; Accuracy: 0.653; IoU: 0.757
# Phase: valid; Loss: 1.795; Accuracy: 0.259; IoU: 0.651
# Epoch 10/100
# ----------
# Phase: train; Loss: 0.851; Accuracy: 0.652; IoU: 0.751
# Phase: valid; Loss: 1.619; Accuracy: 0.291; IoU: 0.724
# Epoch 11/100
# ----------
# Phase: train; Loss: 0.789; Accuracy: 0.682; IoU: 0.780
# Phase: valid; Loss: 1.724; Accuracy: 0.266; IoU: 0.557
# Epoch 12/100
# ----------
# Phase: train; Loss: 0.760; Accuracy: 0.692; IoU: 0.791
# Phase: valid; Loss: 1.147; Accuracy: 0.470; IoU: 0.437
# Epoch 13/100
# ----------
# Phase: train; Loss: 0.774; Accuracy: 0.693; IoU: 0.754
# Phase: valid; Loss: 1.220; Accuracy: 0.388; IoU: 0.347
# Epoch 14/100
# ----------
# Phase: train; Loss: 0.762; Accuracy: 0.684; IoU: 0.767
# Phase: valid; Loss: 1.744; Accuracy: 0.239; IoU: 0.606
# Epoch 15/100
# ----------
# Phase: train; Loss: 0.731; Accuracy: 0.726; IoU: 0.788
# Phase: valid; Loss: 1.131; Accuracy: 0.596; IoU: 0.664
# Epoch 16/100
# ----------
# Phase: train; Loss: 0.705; Accuracy: 0.728; IoU: 0.781
# Phase: valid; Loss: 1.147; Accuracy: 0.547; IoU: 0.537
# Epoch 17/100
# ----------
# Phase: train; Loss: 0.726; Accuracy: 0.736; IoU: 0.804
# Phase: valid; Loss: 1.213; Accuracy: 0.531; IoU: 0.160
# Epoch 18/100
# ----------
# Phase: train; Loss: 0.687; Accuracy: 0.744; IoU: 0.797
# Phase: valid; Loss: 1.160; Accuracy: 0.491; IoU: 0.297
# Epoch 19/100
# ----------
# Phase: train; Loss: 0.677; Accuracy: 0.759; IoU: 0.816
# Phase: valid; Loss: 1.014; Accuracy: 0.600; IoU: 0.516
# Epoch 20/100
# ----------
# Phase: train; Loss: 0.657; Accuracy: 0.767; IoU: 0.819
# Phase: valid; Loss: 1.113; Accuracy: 0.557; IoU: 0.819
# Epoch 21/100
# ----------
# Phase: train; Loss: 0.662; Accuracy: 0.760; IoU: 0.801
# Phase: valid; Loss: 1.184; Accuracy: 0.613; IoU: 0.490
# Epoch 22/100
# ----------
# Phase: train; Loss: 0.631; Accuracy: 0.769; IoU: 0.828
# Phase: valid; Loss: 0.918; Accuracy: 0.645; IoU: 0.497
# Epoch 23/100
# ----------
# Phase: train; Loss: 0.620; Accuracy: 0.780; IoU: 0.832
# Phase: valid; Loss: 0.721; Accuracy: 0.738; IoU: 0.804
# Epoch 24/100
# ----------
# Phase: train; Loss: 0.601; Accuracy: 0.786; IoU: 0.850
# Phase: valid; Loss: 1.107; Accuracy: 0.670; IoU: 0.641
# Epoch 25/100
# ----------
# Phase: train; Loss: 0.594; Accuracy: 0.787; IoU: 0.861
# Phase: valid; Loss: 0.864; Accuracy: 0.692; IoU: 0.806
# Epoch 26/100
# ----------
# Phase: train; Loss: 0.617; Accuracy: 0.775; IoU: 0.834
# Phase: valid; Loss: 1.740; Accuracy: 0.320; IoU: 0.779
# Epoch 27/100
# ----------
# Phase: train; Loss: 0.609; Accuracy: 0.773; IoU: 0.829
# Phase: valid; Loss: 1.260; Accuracy: 0.491; IoU: 0.666
# Epoch 28/100
# ----------
# Phase: train; Loss: 0.605; Accuracy: 0.781; IoU: 0.829
# Phase: valid; Loss: 1.794; Accuracy: 0.397; IoU: 0.226
# Epoch 29/100
# ----------
# Phase: train; Loss: 0.598; Accuracy: 0.778; IoU: 0.831
# Phase: valid; Loss: 1.643; Accuracy: 0.572; IoU: 0.731
# Epoch 30/100
# ----------
# Phase: train; Loss: 0.591; Accuracy: 0.786; IoU: 0.834
# Phase: valid; Loss: 1.585; Accuracy: 0.561; IoU: 0.757
# Epoch 31/100
# ----------
# Phase: train; Loss: 0.580; Accuracy: 0.788; IoU: 0.850
# Phase: valid; Loss: 1.276; Accuracy: 0.575; IoU: 0.657
# Epoch 32/100
# ----------
# Phase: train; Loss: 0.557; Accuracy: 0.792; IoU: 0.846
# Phase: valid; Loss: 1.042; Accuracy: 0.564; IoU: 0.625
# Epoch 33/100
# ----------
# Phase: train; Loss: 0.570; Accuracy: 0.789; IoU: 0.864
# Phase: valid; Loss: 0.810; Accuracy: 0.669; IoU: 0.784
# Epoch 34/100
# ----------
# Phase: train; Loss: 0.548; Accuracy: 0.800; IoU: 0.855
# Phase: valid; Loss: 1.265; Accuracy: 0.457; IoU: 0.635
# Epoch 35/100
# ----------
# Phase: train; Loss: 0.549; Accuracy: 0.800; IoU: 0.848
# Phase: valid; Loss: 1.544; Accuracy: 0.478; IoU: 0.330
# Epoch 36/100
# ----------
# Phase: train; Loss: 0.552; Accuracy: 0.801; IoU: 0.862
# Phase: valid; Loss: 0.954; Accuracy: 0.648; IoU: 0.666
# Epoch 37/100
# ----------
# Phase: train; Loss: 0.537; Accuracy: 0.805; IoU: 0.861
# Phase: valid; Loss: 1.235; Accuracy: 0.591; IoU: 0.760
# Epoch 38/100
# ----------
# Phase: train; Loss: 0.559; Accuracy: 0.794; IoU: 0.857
# Phase: valid; Loss: 0.837; Accuracy: 0.711; IoU: 0.812
# Epoch 39/100
# ----------
# Phase: train; Loss: 0.547; Accuracy: 0.801; IoU: 0.849
# Phase: valid; Loss: 0.898; Accuracy: 0.654; IoU: 0.561
# Epoch 40/100
# ----------
# Phase: train; Loss: 0.517; Accuracy: 0.809; IoU: 0.863
# Phase: valid; Loss: 1.009; Accuracy: 0.677; IoU: 0.805
# Epoch 41/100
# ----------
# Phase: train; Loss: 0.541; Accuracy: 0.801; IoU: 0.855
# Phase: valid; Loss: 1.005; Accuracy: 0.636; IoU: 0.725
# Epoch 42/100
# ----------
# Phase: train; Loss: 0.566; Accuracy: 0.790; IoU: 0.851
# Phase: valid; Loss: 1.487; Accuracy: 0.400; IoU: 0.657
# Epoch 43/100
# ----------
# Phase: train; Loss: 0.540; Accuracy: 0.803; IoU: 0.861
# Phase: valid; Loss: 0.806; Accuracy: 0.688; IoU: 0.805
# Epoch 44/100
# ----------
# Phase: train; Loss: 0.587; Accuracy: 0.781; IoU: 0.851
# Phase: valid; Loss: 1.179; Accuracy: 0.580; IoU: 0.638
# Epoch 45/100
# ----------
# Phase: train; Loss: 0.548; Accuracy: 0.801; IoU: 0.870
# Phase: valid; Loss: 1.029; Accuracy: 0.669; IoU: 0.741
# Epoch 46/100
# ----------
# Phase: train; Loss: 0.573; Accuracy: 0.786; IoU: 0.841
# Phase: valid; Loss: 1.294; Accuracy: 0.454; IoU: 0.595
# Epoch 47/100
# ----------
# Phase: train; Loss: 0.540; Accuracy: 0.799; IoU: 0.849
# Phase: valid; Loss: 1.137; Accuracy: 0.618; IoU: 0.778
# Epoch 48/100
# ----------
# Phase: train; Loss: 0.534; Accuracy: 0.802; IoU: 0.873
# Phase: valid; Loss: 1.067; Accuracy: 0.638; IoU: 0.655
# Epoch 49/100
# ----------
# Phase: train; Loss: 0.512; Accuracy: 0.817; IoU: 0.871
# Phase: valid; Loss: 1.482; Accuracy: 0.591; IoU: 0.684
# Epoch 50/100
# ----------
# Phase: train; Loss: 0.494; Accuracy: 0.823; IoU: 0.875
# Phase: valid; Loss: 0.956; Accuracy: 0.654; IoU: 0.605
# Epoch 51/100
# ----------
# Phase: train; Loss: 0.529; Accuracy: 0.807; IoU: 0.859
# Phase: valid; Loss: 0.996; Accuracy: 0.624; IoU: 0.679
# Epoch 52/100
# ----------
# Phase: train; Loss: 0.501; Accuracy: 0.818; IoU: 0.868
# Phase: valid; Loss: 0.621; Accuracy: 0.773; IoU: 0.763
# Epoch 53/100
# ----------
# Phase: train; Loss: 0.518; Accuracy: 0.810; IoU: 0.870
# Phase: valid; Loss: 0.726; Accuracy: 0.745; IoU: 0.817
# Epoch 54/100
# ----------
# Phase: train; Loss: 0.531; Accuracy: 0.806; IoU: 0.858
# Phase: valid; Loss: 0.954; Accuracy: 0.647; IoU: 0.503
# Epoch 55/100
# ----------
# Phase: train; Loss: 0.481; Accuracy: 0.824; IoU: 0.880
# Phase: valid; Loss: 0.914; Accuracy: 0.659; IoU: 0.655
# Epoch 56/100
# ----------
# Phase: train; Loss: 0.521; Accuracy: 0.810; IoU: 0.864
# Phase: valid; Loss: 1.055; Accuracy: 0.604; IoU: 0.774
# Epoch 57/100
# ----------
# Phase: train; Loss: 0.511; Accuracy: 0.813; IoU: 0.864
# Phase: valid; Loss: 1.108; Accuracy: 0.662; IoU: 0.837
# Epoch 58/100
# ----------
# Phase: train; Loss: 0.520; Accuracy: 0.811; IoU: 0.858
# Phase: valid; Loss: 1.629; Accuracy: 0.402; IoU: 0.619
# Epoch 59/100
# ----------
# Phase: train; Loss: 0.520; Accuracy: 0.810; IoU: 0.859
# Phase: valid; Loss: 0.998; Accuracy: 0.656; IoU: 0.749
# Epoch 60/100
# ----------
# Phase: train; Loss: 0.501; Accuracy: 0.817; IoU: 0.870
# Phase: valid; Loss: 1.130; Accuracy: 0.625; IoU: 0.746
# Epoch 61/100
# ----------
# Phase: train; Loss: 0.490; Accuracy: 0.817; IoU: 0.859
# Phase: valid; Loss: 0.983; Accuracy: 0.690; IoU: 0.728
# Epoch 62/100
# ----------
# Phase: train; Loss: 0.502; Accuracy: 0.818; IoU: 0.863
# Phase: valid; Loss: 1.164; Accuracy: 0.572; IoU: 0.569
# Epoch 63/100
# ----------
# Phase: train; Loss: 0.494; Accuracy: 0.819; IoU: 0.874
# Phase: valid; Loss: 0.968; Accuracy: 0.665; IoU: 0.721
# Epoch 64/100
# ----------
# Phase: train; Loss: 0.445; Accuracy: 0.839; IoU: 0.878
# Phase: valid; Loss: 1.468; Accuracy: 0.557; IoU: 0.690
# Epoch 65/100
# ----------
# Phase: train; Loss: 0.498; Accuracy: 0.818; IoU: 0.868
# Phase: valid; Loss: 0.799; Accuracy: 0.746; IoU: 0.821
# Epoch 66/100
# ----------
# Phase: train; Loss: 0.478; Accuracy: 0.823; IoU: 0.879
# Phase: valid; Loss: 1.701; Accuracy: 0.502; IoU: 0.621
# Epoch 67/100
# ----------
# Phase: train; Loss: 0.464; Accuracy: 0.830; IoU: 0.877
# Phase: valid; Loss: 1.415; Accuracy: 0.535; IoU: 0.625
# Epoch 68/100
# ----------
# Phase: train; Loss: 0.465; Accuracy: 0.833; IoU: 0.889
# Phase: valid; Loss: 1.209; Accuracy: 0.557; IoU: 0.705
# Epoch 69/100
# ----------
# Phase: train; Loss: 0.472; Accuracy: 0.830; IoU: 0.877
# Phase: valid; Loss: 1.076; Accuracy: 0.676; IoU: 0.782
# Epoch 70/100
# ----------
# Phase: train; Loss: 0.487; Accuracy: 0.820; IoU: 0.866
# Phase: valid; Loss: 1.151; Accuracy: 0.594; IoU: 0.788
# Epoch 71/100
# ----------
# Phase: train; Loss: 0.500; Accuracy: 0.812; IoU: 0.860
# Phase: valid; Loss: 1.402; Accuracy: 0.554; IoU: 0.713
# Epoch 72/100
# ----------
# Phase: train; Loss: 0.524; Accuracy: 0.807; IoU: 0.864
# Phase: valid; Loss: 2.792; Accuracy: 0.457; IoU: 0.342
# Epoch 73/100
# ----------
# Phase: train; Loss: 0.494; Accuracy: 0.822; IoU: 0.868
# Phase: valid; Loss: 1.610; Accuracy: 0.382; IoU: 0.702
# Epoch 74/100
# ----------
# Phase: train; Loss: 0.475; Accuracy: 0.827; IoU: 0.873
# Phase: valid; Loss: 1.227; Accuracy: 0.509; IoU: 0.655
# Epoch 75/100
# ----------
# Phase: train; Loss: 0.465; Accuracy: 0.832; IoU: 0.876
# Phase: valid; Loss: 0.972; Accuracy: 0.664; IoU: 0.613
# Epoch 76/100
# ----------
# Phase: train; Loss: 0.453; Accuracy: 0.835; IoU: 0.875
# Phase: valid; Loss: 1.133; Accuracy: 0.664; IoU: 0.754
# Epoch 77/100
# ----------
# Phase: train; Loss: 0.481; Accuracy: 0.822; IoU: 0.869
# Phase: valid; Loss: 0.673; Accuracy: 0.763; IoU: 0.791
# Epoch 78/100
# ----------
# Phase: train; Loss: 0.472; Accuracy: 0.827; IoU: 0.872
# Phase: valid; Loss: 1.606; Accuracy: 0.391; IoU: 0.586
# Epoch 79/100
# ----------
# Phase: train; Loss: 0.469; Accuracy: 0.830; IoU: 0.877
# Phase: valid; Loss: 1.203; Accuracy: 0.607; IoU: 0.581
# Epoch 80/100
# ----------
# Phase: train; Loss: 0.441; Accuracy: 0.837; IoU: 0.881
# Phase: valid; Loss: 1.354; Accuracy: 0.576; IoU: 0.762
# Epoch 81/100
# ----------
# Phase: train; Loss: 0.464; Accuracy: 0.831; IoU: 0.873
# Phase: valid; Loss: 0.668; Accuracy: 0.764; IoU: 0.795
# Epoch 82/100
# ----------
# Phase: train; Loss: 0.465; Accuracy: 0.832; IoU: 0.881
# Phase: valid; Loss: 0.854; Accuracy: 0.694; IoU: 0.773
# Epoch 83/100
# ----------
# Phase: train; Loss: 0.430; Accuracy: 0.843; IoU: 0.883
# Phase: valid; Loss: 1.164; Accuracy: 0.628; IoU: 0.732
# Epoch 84/100
# ----------
# Phase: train; Loss: 0.430; Accuracy: 0.845; IoU: 0.883
# Phase: valid; Loss: 0.821; Accuracy: 0.716; IoU: 0.780
# Epoch 85/100
# ----------
# Phase: train; Loss: 0.433; Accuracy: 0.845; IoU: 0.878
# Phase: valid; Loss: 0.949; Accuracy: 0.689; IoU: 0.590
# Epoch 86/100
# ----------
# Phase: train; Loss: 0.446; Accuracy: 0.838; IoU: 0.882
# Phase: valid; Loss: 1.392; Accuracy: 0.559; IoU: 0.792
# Epoch 87/100
# ----------
# Phase: train; Loss: 0.462; Accuracy: 0.835; IoU: 0.885
# Phase: valid; Loss: 1.471; Accuracy: 0.580; IoU: 0.496
# Epoch 88/100
# ----------
# Phase: train; Loss: 0.455; Accuracy: 0.833; IoU: 0.870
# Phase: valid; Loss: 1.745; Accuracy: 0.503; IoU: 0.670
# Epoch 89/100
# ----------
# Phase: train; Loss: 0.434; Accuracy: 0.844; IoU: 0.876
# Phase: valid; Loss: 1.007; Accuracy: 0.687; IoU: 0.749
# Epoch 90/100
# ----------
# Phase: train; Loss: 0.434; Accuracy: 0.842; IoU: 0.882
# Phase: valid; Loss: 1.054; Accuracy: 0.666; IoU: 0.587
# Epoch 91/100
# ----------
# Phase: train; Loss: 0.413; Accuracy: 0.850; IoU: 0.891
# Phase: valid; Loss: 1.165; Accuracy: 0.599; IoU: 0.720
# Epoch 92/100
# ----------
# Phase: train; Loss: 0.438; Accuracy: 0.845; IoU: 0.883
# Phase: valid; Loss: 1.334; Accuracy: 0.562; IoU: 0.677
# Epoch 93/100
# ----------
# Phase: train; Loss: 0.413; Accuracy: 0.849; IoU: 0.887
# Phase: valid; Loss: 0.650; Accuracy: 0.748; IoU: 0.816
# Epoch 94/100
# ----------
# Phase: train; Loss: 0.412; Accuracy: 0.851; IoU: 0.890
# Phase: valid; Loss: 0.800; Accuracy: 0.713; IoU: 0.727
# Epoch 95/100
# ----------
# Phase: train; Loss: 0.447; Accuracy: 0.839; IoU: 0.883
# Phase: valid; Loss: 1.226; Accuracy: 0.624; IoU: 0.671
# Epoch 96/100
# ----------
# Phase: train; Loss: 0.413; Accuracy: 0.849; IoU: 0.887
# Phase: valid; Loss: 1.050; Accuracy: 0.656; IoU: 0.619
# Epoch 97/100
# ----------
# Phase: train; Loss: 0.399; Accuracy: 0.856; IoU: 0.886
# Phase: valid; Loss: 2.055; Accuracy: 0.482; IoU: 0.683
# Epoch 98/100
# ----------
# Phase: train; Loss: 0.409; Accuracy: 0.854; IoU: 0.893
# Phase: valid; Loss: 1.223; Accuracy: 0.634; IoU: 0.645
# Epoch 99/100
# ----------
# Phase: train; Loss: 0.425; Accuracy: 0.846; IoU: 0.877
# Phase: valid; Loss: 1.133; Accuracy: 0.628; IoU: 0.588
# Epoch 100/100
# ----------
# Phase: train; Loss: 0.398; Accuracy: 0.858; IoU: 0.892
# Phase: valid; Loss: 0.790; Accuracy: 0.739; IoU: 0.769
# Training complete in 2m 22s

# %% [markdown]
# ### 4.6 Save Model

# %%
torch.save(unet_model, os.path.join("UNET", 'wo_transformation_unet_model_128px_100epoches.pt'))
torch.save(unet_model.state_dict(), os.path.join("UNET", 'wo_transformation_unet_model_128px_100epoches_state_dict.pt'))

# %% [markdown]
# ### 4.7 Plot Training and Validation Loss

# %%
plt.plot([t.detach().cpu().numpy() for t in train_loss])

# %%
plt.plot([t.detach().cpu().numpy() for t in valid_loss])

# %% [markdown]
# ### 4.8 Check predictions

# %%
def compute_macro_f1(pred, target, num_classes):
    f1_list = []
    for cls in range(num_classes):
        true_positive = ((pred == cls) & (target == cls)).sum().item()
        false_positive = ((pred == cls) & (target != cls)).sum().item()
        false_negative = ((pred != cls) & (target == cls)).sum().item()

        precision = true_positive / (true_positive + false_positive + 1e-10)
        recall = true_positive / (true_positive + false_negative + 1e-10)
        
        f1 = 2 * (precision * recall) / (precision + recall + 1e-10)
        f1_list.append(f1)
    
    macro_f1 = sum(f1_list) / num_classes
    return macro_f1

# %%
from statistics import mean
def compute_iou(pred, target, num_classes):
    iou_list = []
    for cls in range(num_classes):
        intersection = ((pred == cls) & (target == cls)).sum().item()
        union = ((pred == cls) | (target == cls)).sum().item()
        iou = intersection / (union + 1e-10)
        iou_list.append(iou)
    return iou_list

# %%
for dl in [test_dl]:
    for sample in dl:
        idx = 0
        image = sample["image"].moveaxis(1,3)[idx, :, :, 1]
        target = sample["mask"][idx, :, :]
        pred = unet_model(sample["image"].cuda()).cpu()[0]
        
        print("Actual")
        visualize(image, target)
        print("Predicted")
        visualize(image, torch.argmax(pred, 0))
        
        accuracy = (torch.argmax(pred, 0) == target).float().mean()
        
        macroF1 = compute_macro_f1(torch.argmax(pred, 0), target, 4)
        
        iou_list = compute_iou(torch.argmax(pred, 0), target, 4)
        
        print(f"Test Accuracy: {accuracy:.4f}, "
              f"Test MacroF1: {macroF1:.4f}, "
              f"Test mean IoU: {mean(iou_list)}")
    
        break
# Out:
# Actual
# Predicted
# Test Accuracy: 0.7962, Test MacroF1: 0.4778, Test mean IoU: 0.3936081556967849

# %%
test_acc = []
test_mF1 = []
test_IoU = []
for sample in test_dl:
    # print(sample["image"].shape)
    # print(sample["mask"].shape)
    target = sample["mask"][0, :, :]
    pred = unet_model(sample["image"].cuda()).cpu()[0]
    
    accuracy = (torch.argmax(pred, 0) == target).float().mean()
    test_acc.append(accuracy.tolist())
    macroF1 = compute_macro_f1(torch.argmax(pred, 0), target, 4)
    test_mF1.append(macroF1)
    iou_list = compute_iou(torch.argmax(pred, 0), target, 4)
    test_IoU.append(mean(iou_list))

print(f"Average Test Accuracy: {mean(test_acc):.4f}\n"
      f"Average Test MacroF1: {mean(test_mF1):.4f}\n"
      f"Average Test mean IoU: {mean(test_IoU):.4f}")   

# Set the x axis label of the current axis.
plt.xlabel('Bacth No.')
# Set the y axis label of the current axis.
plt.ylabel('Metric')
# Set a title 
plt.title('Test Data set evaluation batch-wise')
# Display the figure.
plt.plot(range(1, len(test_acc)+1), test_acc, color='blue', linewidth = 1,  label = 'Accruacy')
plt.plot(range(1, len(test_mF1)+1), test_mF1, color='yellow', linewidth = 1,  label = 'Macro F1')
plt.plot(range(1, len(test_IoU)+1), test_IoU, color='red', linewidth = 1,  label = 'IoU')
# show a legend on the plot
plt.legend()
plt.show()
# Out:
# Average Test Accuracy: 0.6420
# Average Test MacroF1: 0.4844
# Average Test mean IoU: 0.3819

# %%
#Additional Info when using cuda
if DEVICE.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# NVIDIA GeForce RTX 2060 SUPER
# Memory Usage:
# Allocated: 0.1 GB
# Cached:    3.1 GB
