# %% [markdown]
# # Multiclass semantic segmentation with U-Net

# %% [markdown]
# ## 1.0 Import libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
import torch
from torch import nn
from torchgeo.samplers import RandomGeoSampler
from torch.utils.data import DataLoader
from torchgeo.datasets import stack_samples
from torchgeo.datasets import RasterDataset
from torchsummary import summary
#import pylab as plt
# torch.cuda.is_available()

# %% [markdown]
# ## 2.0 Check CUDA availability

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', DEVICE)
print()
# Out:
# Using device: cuda

# %%
#Additional Info when using cuda
if DEVICE.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# NVIDIA GeForce RTX 2060 SUPER
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %% [markdown]
# ## 3.0 Load and prepare dataset

# %%
# Create CLASS for images and labels
class BengaluruDatasetImages(RasterDataset):
    """
    Load image data that ends in *.tif
    """
    filename_glob = "*.tif"
    

class BengaluruDatasetLabels(RasterDataset):
    """
    Load label data that ends in *.tif
    """
    is_image = False
    filename_glob = "*.tif"

# %%
# base path of the dataset
TRAIN_PATH = os.path.join("Data", "Train")
VALID_PATH = os.path.join("Data", "Valid")
TEST_PATH = os.path.join("Data", "Test2")
#tr_labels = lambda x: x[:,0,:,:].long()

# %%
# Create CLASS for image and label transformation

class TransformBengaluruImages(nn.Module):
    """
    Apply Min and Max scale to the image
    """

    def __init__(self):
        super().__init__()

    def forward(self, inputs):
        inputs["image"] -= inputs["image"].min()
        inputs["image"] /= inputs["image"].max()
        
        return inputs
    
class TransformBengaluruLabels(nn.Module):
    """
    Create additional dimensions for the labels np arrays
    """

    def __init__(self):
        super().__init__()

    def forward(self, inputs):
        # Batch
        if inputs["mask"].ndim == 4:
            inputs["mask"] = (inputs["mask"][:,0,:,:]).long()
        # Sample
        else:
            inputs["mask"] = (inputs["mask"][0,:,:]).long()
        
        return inputs

# %%
# Create Train and Test datasets
tr_im = BengaluruDatasetImages(os.path.join(TRAIN_PATH, "Images"), transforms=TransformBengaluruImages())
tr_la = BengaluruDatasetLabels(os.path.join(TRAIN_PATH, "Labels"), transforms=TransformBengaluruLabels())

TRAIN_DS = tr_im & tr_la

# Create Train and Test datasets
vl_im = BengaluruDatasetImages(os.path.join(VALID_PATH, "Images"), transforms=TransformBengaluruImages())
vl_la = BengaluruDatasetLabels(os.path.join(VALID_PATH, "Labels"), transforms=TransformBengaluruLabels())

VALID_DS = vl_im & vl_la

ts_im = BengaluruDatasetImages(os.path.join(TEST_PATH, "Images"), transforms=TransformBengaluruImages())
ts_la = BengaluruDatasetLabels(os.path.join(TEST_PATH, "Labels"), transforms=TransformBengaluruLabels())

TEST_DS = ts_im & ts_la

# %%
# Define dataset, batch, and image sizes
DATASET_SIZE = 512
BATCH_SIZE = 64
IMG_SIZE = 128

# %%
train_sampler = RandomGeoSampler(TRAIN_DS, size=IMG_SIZE, length=DATASET_SIZE)
valid_sampler = RandomGeoSampler(VALID_DS, size=IMG_SIZE, length=72)
test_sampler = RandomGeoSampler(TEST_DS, size=IMG_SIZE, length=144)

train_dl = DataLoader(TRAIN_DS, BATCH_SIZE, sampler=train_sampler, collate_fn=stack_samples)
valid_dl = DataLoader(VALID_DS, BATCH_SIZE, sampler=valid_sampler, collate_fn=stack_samples)
test_dl  = DataLoader(TEST_DS, 1, sampler=test_sampler, collate_fn=stack_samples)

# %%
import matplotlib as mpl
cmap_custom = (mpl.colors.ListedColormap(['slategray', 'sandybrown', 'greenyellow', 'forestgreen']))
        # .with_extremes(over='0.25', under='0.75'))
def visualize(image, mask):
    """PLot images in one row."""
    fig = plt.figure(figsize=(16, 8))
    #plt.imshow(image[0].transpose(0,2), vmin=0, vmax=1)
    image /= image.numpy().max()
    plt.imshow(image, cmap='gray')
    #plt.imshow(image[0])
    if mask.max()>0:
        plt.imshow(mask/3, alpha=0.6, cmap=cmap_custom, vmin=0, vmax=1, interpolation='nearest')
      
    cb = plt.colorbar(cmap=cmap_custom, ticks=np.array([0.125, 0.375, 0.625, 0.875]), boundaries=np.array([0., 0.25, 0.5, 0.75, 1]))
    # ticks=np.linspace(0.5/9, 3.5/9, 4), boundaries=np.linspace(0,4/9,5))
    cb.set_ticklabels(['Background', 'Fallow', 'Herbaceous', 'Woody'])
    plt.show()

for dl in [train_dl, valid_dl, test_dl]:
    for sample in dl:
        idx = 0
        image = sample["image"].moveaxis(1,3)[idx, :, :, 1]
        target = sample["mask"][idx, :, :]
        
        visualize(image, target)
        break

# %% [markdown]
# ## 4.0 Model definition

# %% [markdown]
# ### 4.1 UNET Class define

# %%
# Creat UNET CLASS
class UNET(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.conv1 = self.contract_block(in_channels, 32, 3, 1)
        self.conv2 = self.contract_block(32, 64, 3, 1)
        self.conv3 = self.contract_block(64, 128, 3, 1)
        self.conv4 = self.contract_block(128, 256, 3, 1)

        self.upconv4 = self.expand_block(256, 128, 3, 1)
        self.upconv3 = self.expand_block(128*2, 64, 3, 1)
        self.upconv2 = self.expand_block(64*2, 32, 3, 1)
        self.upconv1 = self.expand_block(32*2, out_channels, 3, 1)

    def __call__(self, x):

        # downsampling part
        conv1 = self.conv1(x)
        conv2 = self.conv2(conv1)
        conv3 = self.conv3(conv2)
        conv4 = self.conv4(conv3)

        upconv4 = self.upconv4(conv4)
        upconv3 = self.upconv3(torch.cat([upconv4, conv3], 1))
        upconv2 = self.upconv2(torch.cat([upconv3, conv2], 1))
        upconv1 = self.upconv1(torch.cat([upconv2, conv1], 1))

        return upconv1

    def contract_block(self, in_channels, out_channels, kernel_size, padding):

        contract = nn.Sequential(
            torch.nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, stride=1, padding=padding),
            torch.nn.BatchNorm2d(out_channels),
            torch.nn.ReLU(),
            torch.nn.Conv2d(out_channels, out_channels, kernel_size=kernel_size, stride=1, padding=padding),
            torch.nn.BatchNorm2d(out_channels),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )

        return contract

    def expand_block(self, in_channels, out_channels, kernel_size, padding):

        expand = nn.Sequential(torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding=padding),
                            torch.nn.BatchNorm2d(out_channels),
                            torch.nn.ReLU(),
                            torch.nn.Conv2d(out_channels, out_channels, kernel_size, stride=1, padding=padding),
                            torch.nn.BatchNorm2d(out_channels),
                            torch.nn.ReLU(),
                            torch.nn.ConvTranspose2d(out_channels, out_channels, kernel_size=3, stride=2, padding=1, output_padding=1) 
                            )
        return expand

# %%
# Example usage
in_channels = 5  # Number of input channels (e.g., for WV images)
out_channels = 4  # Number of output channels (e.g., number of classes)
test_model = UNET(in_channels, out_channels)
input_tensor = torch.randn(1, in_channels, 128, 128)  # Example input tensor
output_tensor = test_model(input_tensor)
print(output_tensor.shape)
# Out:
# torch.Size([1, 4, 128, 128])

# %% [markdown]
# ### 4.2 View the summary of the model

# %%
unet_model =  UNET(in_channels=5, out_channels=4).to(DEVICE)

# %% [markdown]
# ### 4.3 Define model parameters

# %%
LEARNING_RATE = 0.01
num_epochs = 100
loss_fn = nn.CrossEntropyLoss(ignore_index=255)
opt = torch.optim.Adam(unet_model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# ### 4.4 Create TRAIN function

# %%
import time
def train(model, train_dl, valid_dl, loss_fn, optimizer, acc_fn, iou_fn, epochs=1):
    start = time.time()
    model

    train_loss, valid_loss = [], []

    best_acc = 0.0

    for epoch in range(epochs):
        print('Epoch {}/{}'.format(epoch+1, epochs))
        print('-' * 10)

        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train(True)  # Set trainind mode = true
                dataloader = train_dl
            else:
                model.train(False)  # Set model to evaluate mode
                dataloader = valid_dl

            running_loss = 0.0
            running_acc = 0.0
            running_iou = 0.0

            step = 0

            # iterate over data
            for sampl in dataloader:
                x = sampl['image'].to(DEVICE)
                y = sampl['mask'].to(DEVICE)
                
                if x.isnan().any():
                    print('x nan')
                if y.isnan().any():
                    print('y nan')
                
                step += 1

                # forward pass
                if phase == 'train':
                    # zero the gradients
                    optimizer.zero_grad()
                    outputs = model(x)
                    
                    if outputs.isnan().any():
                        print('outputs nan')
                        break
                    loss = loss_fn(outputs, y)
                    

                    # the backward pass frees the graph memory, so there is no 
                    # need for torch.no_grad in this training pass
                    loss.backward()
                    optimizer.step()
                    # scheduler.step()

                else:
                    with torch.no_grad():
                        outputs = model(x)
                        loss = loss_fn(outputs, y.long())

                # stats - whatever is the phase
                acc = acc_fn(outputs, y)
                iou = iou_fn(outputs, y)

                running_acc  += acc
                running_loss += loss
                running_iou += iou
                

                if step % 20 == 0:
                    # clear_output(wait=True)
                    # print('Current step: {}  Loss: {}  Acc: {} '.format(step, loss, acc))
                    print('Current step: {};  Loss: {:.3f};  Accuracy: {:.3f}; IoU: {:.3f}; AllocMem (Mb): {:.3f}'.format(step, loss, acc, iou, torch.cuda.memory_allocated()/1024/1024))
                    # print(torch.cuda.memory_summary())
            

            epoch_loss = running_loss / step
            epoch_acc = running_acc / step
            epoch_iou = running_iou / step

            print('Phase: {}; Loss: {:.3f}; Accuracy: {:.3f}; IoU: {:.3f}'.format(phase, epoch_loss, epoch_acc, epoch_iou))

            train_loss.append(epoch_loss) if phase=='train' else valid_loss.append(epoch_loss)

    time_elapsed = time.time() - start
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))    
    
    return train_loss, valid_loss    

def acc_metric(predb, yb):
    return (predb.argmax(dim=1) == yb.to(DEVICE)).float().mean()

def iou_metric(predb, yb):
    intersection = (torch.logical_and(predb.argmax(dim=1), yb.to(DEVICE).float())).sum(()).float()
    union = (torch.logical_or(predb.argmax(dim=1), yb.to(DEVICE)).float()).sum(()).float()
    iou = (intersection + 1e-7) / (union + 1e-7)
    return iou.mean()

# %% [markdown]
# ### 4.5 Model training

# %%
train_loss, valid_loss = train(model=unet_model, 
                               train_dl=train_dl, 
                               valid_dl=train_dl, 
                               loss_fn=loss_fn, 
                               optimizer=opt, 
                               acc_fn=acc_metric, 
                               iou_fn = iou_metric, 
                               epochs=num_epochs)
# Out:
# Epoch 1/100
# ----------
# Phase: train; Loss: 1.345; Accuracy: 0.341; IoU: 0.481
# Phase: valid; Loss: 3.044; Accuracy: 0.345; IoU: 0.742
# Epoch 2/100
# ----------
# Phase: train; Loss: 1.158; Accuracy: 0.579; IoU: 0.656
# Phase: valid; Loss: 1.206; Accuracy: 0.550; IoU: 0.726
# Epoch 3/100
# ----------
# Phase: train; Loss: 0.985; Accuracy: 0.664; IoU: 0.737
# Phase: valid; Loss: 1.047; Accuracy: 0.581; IoU: 0.744
# Epoch 4/100
# ----------
# Phase: train; Loss: 0.949; Accuracy: 0.651; IoU: 0.733
# Phase: valid; Loss: 1.101; Accuracy: 0.623; IoU: 0.756
# Epoch 5/100
# ----------
# Phase: train; Loss: 0.865; Accuracy: 0.679; IoU: 0.733
# Phase: valid; Loss: 0.972; Accuracy: 0.623; IoU: 0.616
# Epoch 6/100
# ----------
# Phase: train; Loss: 0.834; Accuracy: 0.685; IoU: 0.770
# Phase: valid; Loss: 1.190; Accuracy: 0.461; IoU: 0.439
# Epoch 7/100
# ----------
# Phase: train; Loss: 0.831; Accuracy: 0.670; IoU: 0.701
# Phase: valid; Loss: 1.011; Accuracy: 0.573; IoU: 0.574
# Epoch 8/100
# ----------
# Phase: train; Loss: 0.777; Accuracy: 0.709; IoU: 0.767
# Phase: valid; Loss: 0.799; Accuracy: 0.714; IoU: 0.777
# Epoch 9/100
# ----------
# Phase: train; Loss: 0.784; Accuracy: 0.701; IoU: 0.765
# Phase: valid; Loss: 0.948; Accuracy: 0.588; IoU: 0.556
# Epoch 10/100
# ----------
# Phase: train; Loss: 0.755; Accuracy: 0.713; IoU: 0.755
# Phase: valid; Loss: 1.013; Accuracy: 0.640; IoU: 0.809
# Epoch 11/100
# ----------
# Phase: train; Loss: 0.726; Accuracy: 0.726; IoU: 0.784
# Phase: valid; Loss: 1.860; Accuracy: 0.449; IoU: 0.574
# Epoch 12/100
# ----------
# Phase: train; Loss: 0.740; Accuracy: 0.713; IoU: 0.780
# Phase: valid; Loss: 0.820; Accuracy: 0.680; IoU: 0.705
# Epoch 13/100
# ----------
# Phase: train; Loss: 0.689; Accuracy: 0.726; IoU: 0.814
# Phase: valid; Loss: 0.793; Accuracy: 0.711; IoU: 0.820
# Epoch 14/100
# ----------
# Phase: train; Loss: 0.651; Accuracy: 0.751; IoU: 0.829
# Phase: valid; Loss: 1.034; Accuracy: 0.626; IoU: 0.781
# Epoch 15/100
# ----------
# Phase: train; Loss: 0.659; Accuracy: 0.745; IoU: 0.814
# Phase: valid; Loss: 0.712; Accuracy: 0.722; IoU: 0.775
# Epoch 16/100
# ----------
# Phase: train; Loss: 0.694; Accuracy: 0.733; IoU: 0.813
# Phase: valid; Loss: 0.887; Accuracy: 0.660; IoU: 0.794
# Epoch 17/100
# ----------
# Phase: train; Loss: 0.662; Accuracy: 0.748; IoU: 0.819
# Phase: valid; Loss: 0.697; Accuracy: 0.726; IoU: 0.788
# Epoch 18/100
# ----------
# Phase: train; Loss: 0.636; Accuracy: 0.762; IoU: 0.848
# Phase: valid; Loss: 0.919; Accuracy: 0.614; IoU: 0.664
# Epoch 19/100
# ----------
# Phase: train; Loss: 0.613; Accuracy: 0.776; IoU: 0.843
# Phase: valid; Loss: 1.202; Accuracy: 0.552; IoU: 0.767
# Epoch 20/100
# ----------
# Phase: train; Loss: 0.641; Accuracy: 0.765; IoU: 0.844
# Phase: valid; Loss: 0.957; Accuracy: 0.657; IoU: 0.729
# Epoch 21/100
# ----------
# Phase: train; Loss: 0.635; Accuracy: 0.762; IoU: 0.832
# Phase: valid; Loss: 1.049; Accuracy: 0.620; IoU: 0.806
# Epoch 22/100
# ----------
# Phase: train; Loss: 0.597; Accuracy: 0.781; IoU: 0.837
# Phase: valid; Loss: 1.012; Accuracy: 0.630; IoU: 0.707
# Epoch 23/100
# ----------
# Phase: train; Loss: 0.589; Accuracy: 0.785; IoU: 0.853
# Phase: valid; Loss: 0.752; Accuracy: 0.731; IoU: 0.816
# Epoch 24/100
# ----------
# Phase: train; Loss: 0.601; Accuracy: 0.783; IoU: 0.854
# Phase: valid; Loss: 0.918; Accuracy: 0.589; IoU: 0.813
# Epoch 25/100
# ----------
# Phase: train; Loss: 0.582; Accuracy: 0.783; IoU: 0.839
# Phase: valid; Loss: 1.102; Accuracy: 0.637; IoU: 0.649
# Epoch 26/100
# ----------
# Phase: train; Loss: 0.599; Accuracy: 0.781; IoU: 0.839
# Phase: valid; Loss: 0.643; Accuracy: 0.750; IoU: 0.806
# Epoch 27/100
# ----------
# Phase: train; Loss: 0.606; Accuracy: 0.776; IoU: 0.838
# Phase: valid; Loss: 0.676; Accuracy: 0.747; IoU: 0.851
# Epoch 28/100
# ----------
# Phase: train; Loss: 0.584; Accuracy: 0.785; IoU: 0.854
# Phase: valid; Loss: 0.685; Accuracy: 0.745; IoU: 0.839
# Epoch 29/100
# ----------
# Phase: train; Loss: 0.573; Accuracy: 0.789; IoU: 0.857
# Phase: valid; Loss: 0.624; Accuracy: 0.784; IoU: 0.856
# Epoch 30/100
# ----------
# Phase: train; Loss: 0.568; Accuracy: 0.790; IoU: 0.855
# Phase: valid; Loss: 0.675; Accuracy: 0.747; IoU: 0.839
# Epoch 31/100
# ----------
# Phase: train; Loss: 0.552; Accuracy: 0.802; IoU: 0.859
# Phase: valid; Loss: 0.640; Accuracy: 0.758; IoU: 0.857
# Epoch 32/100
# ----------
# Phase: train; Loss: 0.566; Accuracy: 0.796; IoU: 0.867
# Phase: valid; Loss: 0.810; Accuracy: 0.711; IoU: 0.778
# Epoch 33/100
# ----------
# Phase: train; Loss: 0.557; Accuracy: 0.793; IoU: 0.856
# Phase: valid; Loss: 0.723; Accuracy: 0.745; IoU: 0.848
# Epoch 34/100
# ----------
# Phase: train; Loss: 0.560; Accuracy: 0.791; IoU: 0.851
# Phase: valid; Loss: 0.867; Accuracy: 0.677; IoU: 0.631
# Epoch 35/100
# ----------
# Phase: train; Loss: 0.571; Accuracy: 0.786; IoU: 0.849
# Phase: valid; Loss: 1.247; Accuracy: 0.610; IoU: 0.619
# Epoch 36/100
# ----------
# Phase: train; Loss: 0.562; Accuracy: 0.791; IoU: 0.843
# Phase: valid; Loss: 0.655; Accuracy: 0.765; IoU: 0.852
# Epoch 37/100
# ----------
# Phase: train; Loss: 0.523; Accuracy: 0.808; IoU: 0.867
# Phase: valid; Loss: 0.777; Accuracy: 0.705; IoU: 0.827
# Epoch 38/100
# ----------
# Phase: train; Loss: 0.536; Accuracy: 0.807; IoU: 0.869
# Phase: valid; Loss: 0.606; Accuracy: 0.779; IoU: 0.849
# Epoch 39/100
# ----------
# Phase: train; Loss: 0.559; Accuracy: 0.796; IoU: 0.855
# Phase: valid; Loss: 0.825; Accuracy: 0.699; IoU: 0.799
# Epoch 40/100
# ----------
# Phase: train; Loss: 0.532; Accuracy: 0.801; IoU: 0.859
# Phase: valid; Loss: 0.575; Accuracy: 0.790; IoU: 0.842
# Epoch 41/100
# ----------
# Phase: train; Loss: 0.516; Accuracy: 0.811; IoU: 0.873
# Phase: valid; Loss: 0.602; Accuracy: 0.768; IoU: 0.813
# Epoch 42/100
# ----------
# Phase: train; Loss: 0.545; Accuracy: 0.800; IoU: 0.870
# Phase: valid; Loss: 0.847; Accuracy: 0.692; IoU: 0.804
# Epoch 43/100
# ----------
# Phase: train; Loss: 0.526; Accuracy: 0.806; IoU: 0.863
# Phase: valid; Loss: 0.593; Accuracy: 0.781; IoU: 0.872
# Epoch 44/100
# ----------
# Phase: train; Loss: 0.539; Accuracy: 0.801; IoU: 0.862
# Phase: valid; Loss: 0.735; Accuracy: 0.719; IoU: 0.816
# Epoch 45/100
# ----------
# Phase: train; Loss: 0.510; Accuracy: 0.812; IoU: 0.861
# Phase: valid; Loss: 0.894; Accuracy: 0.694; IoU: 0.709
# Epoch 46/100
# ----------
# Phase: train; Loss: 0.518; Accuracy: 0.814; IoU: 0.862
# Phase: valid; Loss: 0.732; Accuracy: 0.728; IoU: 0.771
# Epoch 47/100
# ----------
# Phase: train; Loss: 0.511; Accuracy: 0.813; IoU: 0.872
# Phase: valid; Loss: 0.590; Accuracy: 0.783; IoU: 0.854
# Epoch 48/100
# ----------
# Phase: train; Loss: 0.522; Accuracy: 0.807; IoU: 0.880
# Phase: valid; Loss: 0.777; Accuracy: 0.720; IoU: 0.822
# Epoch 49/100
# ----------
# Phase: train; Loss: 0.526; Accuracy: 0.808; IoU: 0.868
# Phase: valid; Loss: 0.720; Accuracy: 0.727; IoU: 0.812
# Epoch 50/100
# ----------
# Phase: train; Loss: 0.523; Accuracy: 0.805; IoU: 0.862
# Phase: valid; Loss: 0.664; Accuracy: 0.750; IoU: 0.781
# Epoch 51/100
# ----------
# Phase: train; Loss: 0.503; Accuracy: 0.811; IoU: 0.867
# Phase: valid; Loss: 0.671; Accuracy: 0.758; IoU: 0.857
# Epoch 52/100
# ----------
# Phase: train; Loss: 0.545; Accuracy: 0.804; IoU: 0.867
# Phase: valid; Loss: 0.560; Accuracy: 0.792; IoU: 0.842
# Epoch 53/100
# ----------
# Phase: train; Loss: 0.506; Accuracy: 0.815; IoU: 0.869
# Phase: valid; Loss: 1.538; Accuracy: 0.572; IoU: 0.473
# Epoch 54/100
# ----------
# Phase: train; Loss: 0.522; Accuracy: 0.810; IoU: 0.868
# Phase: valid; Loss: 0.655; Accuracy: 0.759; IoU: 0.849
# Epoch 55/100
# ----------
# Phase: train; Loss: 0.521; Accuracy: 0.812; IoU: 0.877
# Phase: valid; Loss: 0.631; Accuracy: 0.762; IoU: 0.860
# Epoch 56/100
# ----------
# Phase: train; Loss: 0.507; Accuracy: 0.813; IoU: 0.869
# Phase: valid; Loss: 0.622; Accuracy: 0.774; IoU: 0.799
# Epoch 57/100
# ----------
# Phase: train; Loss: 0.515; Accuracy: 0.815; IoU: 0.872
# Phase: valid; Loss: 0.620; Accuracy: 0.764; IoU: 0.840
# Epoch 58/100
# ----------
# Phase: train; Loss: 0.504; Accuracy: 0.816; IoU: 0.873
# Phase: valid; Loss: 0.520; Accuracy: 0.807; IoU: 0.865
# Epoch 59/100
# ----------
# Phase: train; Loss: 0.494; Accuracy: 0.823; IoU: 0.878
# Phase: valid; Loss: 0.526; Accuracy: 0.811; IoU: 0.869
# Epoch 60/100
# ----------
# Phase: train; Loss: 0.504; Accuracy: 0.818; IoU: 0.869
# Phase: valid; Loss: 0.753; Accuracy: 0.745; IoU: 0.769
# Epoch 61/100
# ----------
# Phase: train; Loss: 0.497; Accuracy: 0.814; IoU: 0.874
# Phase: valid; Loss: 0.618; Accuracy: 0.767; IoU: 0.821
# Epoch 62/100
# ----------
# Phase: train; Loss: 0.497; Accuracy: 0.822; IoU: 0.884
# Phase: valid; Loss: 0.660; Accuracy: 0.731; IoU: 0.841
# Epoch 63/100
# ----------
# Phase: train; Loss: 0.481; Accuracy: 0.821; IoU: 0.866
# Phase: valid; Loss: 0.555; Accuracy: 0.792; IoU: 0.842
# Epoch 64/100
# ----------
# Phase: train; Loss: 0.469; Accuracy: 0.835; IoU: 0.883
# Phase: valid; Loss: 0.546; Accuracy: 0.797; IoU: 0.867
# Epoch 65/100
# ----------
# Phase: train; Loss: 0.475; Accuracy: 0.825; IoU: 0.874
# Phase: valid; Loss: 0.560; Accuracy: 0.791; IoU: 0.852
# Epoch 66/100
# ----------
# Phase: train; Loss: 0.472; Accuracy: 0.826; IoU: 0.873
# Phase: valid; Loss: 0.588; Accuracy: 0.783; IoU: 0.797
# Epoch 67/100
# ----------
# Phase: train; Loss: 0.455; Accuracy: 0.835; IoU: 0.882
# Phase: valid; Loss: 0.721; Accuracy: 0.716; IoU: 0.830
# Epoch 68/100
# ----------
# Phase: train; Loss: 0.483; Accuracy: 0.824; IoU: 0.871
# Phase: valid; Loss: 0.476; Accuracy: 0.829; IoU: 0.881
# Epoch 69/100
# ----------
# Phase: train; Loss: 0.492; Accuracy: 0.818; IoU: 0.875
# Phase: valid; Loss: 0.496; Accuracy: 0.818; IoU: 0.873
# Epoch 70/100
# ----------
# Phase: train; Loss: 0.461; Accuracy: 0.833; IoU: 0.875
# Phase: valid; Loss: 0.666; Accuracy: 0.775; IoU: 0.858
# Epoch 71/100
# ----------
# Phase: train; Loss: 0.459; Accuracy: 0.835; IoU: 0.888
# Phase: valid; Loss: 0.713; Accuracy: 0.732; IoU: 0.849
# Epoch 72/100
# ----------
# Phase: train; Loss: 0.488; Accuracy: 0.819; IoU: 0.866
# Phase: valid; Loss: 0.520; Accuracy: 0.814; IoU: 0.876
# Epoch 73/100
# ----------
# Phase: train; Loss: 0.465; Accuracy: 0.831; IoU: 0.884
# Phase: valid; Loss: 0.610; Accuracy: 0.778; IoU: 0.853
# Epoch 74/100
# ----------
# Phase: train; Loss: 0.473; Accuracy: 0.828; IoU: 0.882
# Phase: valid; Loss: 0.672; Accuracy: 0.743; IoU: 0.850
# Epoch 75/100
# ----------
# Phase: train; Loss: 0.478; Accuracy: 0.823; IoU: 0.870
# Phase: valid; Loss: 0.524; Accuracy: 0.804; IoU: 0.876
# Epoch 76/100
# ----------
# Phase: train; Loss: 0.468; Accuracy: 0.827; IoU: 0.884
# Phase: valid; Loss: 0.649; Accuracy: 0.776; IoU: 0.818
# Epoch 77/100
# ----------
# Phase: train; Loss: 0.448; Accuracy: 0.836; IoU: 0.871
# Phase: valid; Loss: 0.621; Accuracy: 0.772; IoU: 0.834
# Epoch 78/100
# ----------
# Phase: train; Loss: 0.472; Accuracy: 0.828; IoU: 0.884
# Phase: valid; Loss: 0.479; Accuracy: 0.828; IoU: 0.876
# Epoch 79/100
# ----------
# Phase: train; Loss: 0.449; Accuracy: 0.837; IoU: 0.887
# Phase: valid; Loss: 0.529; Accuracy: 0.805; IoU: 0.836
# Epoch 80/100
# ----------
# Phase: train; Loss: 0.453; Accuracy: 0.838; IoU: 0.890
# Phase: valid; Loss: 0.494; Accuracy: 0.818; IoU: 0.870
# Epoch 81/100
# ----------
# Phase: train; Loss: 0.458; Accuracy: 0.834; IoU: 0.884
# Phase: valid; Loss: 0.913; Accuracy: 0.645; IoU: 0.802
# Epoch 82/100
# ----------
# Phase: train; Loss: 0.470; Accuracy: 0.825; IoU: 0.868
# Phase: valid; Loss: 0.732; Accuracy: 0.750; IoU: 0.836
# Epoch 83/100
# ----------
# Phase: train; Loss: 0.468; Accuracy: 0.833; IoU: 0.878
# Phase: valid; Loss: 0.549; Accuracy: 0.794; IoU: 0.839
# Epoch 84/100
# ----------
# Phase: train; Loss: 0.462; Accuracy: 0.833; IoU: 0.881
# Phase: valid; Loss: 0.571; Accuracy: 0.784; IoU: 0.864
# Epoch 85/100
# ----------
# Phase: train; Loss: 0.438; Accuracy: 0.845; IoU: 0.884
# Phase: valid; Loss: 0.489; Accuracy: 0.817; IoU: 0.874
# Epoch 86/100
# ----------
# Phase: train; Loss: 0.447; Accuracy: 0.839; IoU: 0.887
# Phase: valid; Loss: 0.678; Accuracy: 0.748; IoU: 0.871
# Epoch 87/100
# ----------
# Phase: train; Loss: 0.444; Accuracy: 0.839; IoU: 0.872
# Phase: valid; Loss: 0.640; Accuracy: 0.769; IoU: 0.837
# Epoch 88/100
# ----------
# Phase: train; Loss: 0.462; Accuracy: 0.830; IoU: 0.880
# Phase: valid; Loss: 0.575; Accuracy: 0.778; IoU: 0.859
# Epoch 89/100
# ----------
# Phase: train; Loss: 0.442; Accuracy: 0.840; IoU: 0.884
# Phase: valid; Loss: 0.586; Accuracy: 0.776; IoU: 0.881
# Epoch 90/100
# ----------
# Phase: train; Loss: 0.455; Accuracy: 0.837; IoU: 0.877
# Phase: valid; Loss: 0.505; Accuracy: 0.817; IoU: 0.871
# Epoch 91/100
# ----------
# Phase: train; Loss: 0.432; Accuracy: 0.844; IoU: 0.883
# Phase: valid; Loss: 1.800; Accuracy: 0.396; IoU: 0.626
# Epoch 92/100
# ----------
# Phase: train; Loss: 0.458; Accuracy: 0.836; IoU: 0.888
# Phase: valid; Loss: 1.047; Accuracy: 0.630; IoU: 0.797
# Epoch 93/100
# ----------
# Phase: train; Loss: 0.466; Accuracy: 0.832; IoU: 0.880
# Phase: valid; Loss: 0.883; Accuracy: 0.698; IoU: 0.797
# Epoch 94/100
# ----------
# Phase: train; Loss: 0.438; Accuracy: 0.837; IoU: 0.886
# Phase: valid; Loss: 0.473; Accuracy: 0.826; IoU: 0.863
# Epoch 95/100
# ----------
# Phase: train; Loss: 0.434; Accuracy: 0.841; IoU: 0.883
# Phase: valid; Loss: 0.520; Accuracy: 0.808; IoU: 0.841
# Epoch 96/100
# ----------
# Phase: train; Loss: 0.448; Accuracy: 0.834; IoU: 0.880
# Phase: valid; Loss: 0.601; Accuracy: 0.780; IoU: 0.851
# Epoch 97/100
# ----------
# Phase: train; Loss: 0.434; Accuracy: 0.841; IoU: 0.879
# Phase: valid; Loss: 0.523; Accuracy: 0.809; IoU: 0.875
# Epoch 98/100
# ----------
# Phase: train; Loss: 0.406; Accuracy: 0.853; IoU: 0.899
# Phase: valid; Loss: 0.506; Accuracy: 0.813; IoU: 0.877
# Epoch 99/100
# ----------
# Phase: train; Loss: 0.454; Accuracy: 0.832; IoU: 0.873
# Phase: valid; Loss: 0.658; Accuracy: 0.761; IoU: 0.819
# Epoch 100/100
# ----------
# Phase: train; Loss: 0.444; Accuracy: 0.839; IoU: 0.884
# Phase: valid; Loss: 0.829; Accuracy: 0.725; IoU: 0.863
# Training complete in 3m 41s

# %% [markdown]
# ### 4.6 Save Model

# %%
torch.save(unet_model, os.path.join("UNET", 'trainavalid_unet_model_128px_100epoches.pt'))
torch.save(unet_model.state_dict(), os.path.join("UNET", 'trainavalid_unet_model_128px_100epoches_state_dict.pt'))

# %% [markdown]
# ### 4.7 Plot Training and Validation Loss

# %%
plt.plot([t.detach().cpu().numpy() for t in train_loss])

# %%
plt.plot([t.detach().cpu().numpy() for t in valid_loss])

# %% [markdown]
# ### 4.8 Check predictions

# %%
def compute_macro_f1(pred, target, num_classes):
    f1_list = []
    for cls in range(num_classes):
        true_positive = ((pred == cls) & (target == cls)).sum().item()
        false_positive = ((pred == cls) & (target != cls)).sum().item()
        false_negative = ((pred != cls) & (target == cls)).sum().item()

        precision = true_positive / (true_positive + false_positive + 1e-10)
        recall = true_positive / (true_positive + false_negative + 1e-10)
        
        f1 = 2 * (precision * recall) / (precision + recall + 1e-10)
        f1_list.append(f1)
    
    macro_f1 = sum(f1_list) / num_classes
    return macro_f1

# %%
from statistics import mean
def compute_iou(pred, target, num_classes):
    iou_list = []
    for cls in range(num_classes):
        intersection = ((pred == cls) & (target == cls)).sum().item()
        union = ((pred == cls) | (target == cls)).sum().item()
        iou = intersection / (union + 1e-10)
        iou_list.append(iou)
    return iou_list

# %%
for dl in [test_dl]:
    for sample in dl:
        idx = 0
        image = sample["image"].moveaxis(1,3)[idx, :, :, 1]
        target = sample["mask"][idx, :, :]
        pred = unet_model(sample["image"].cuda()).cpu()[0]
        
        print("Actual")
        visualize(image, target)
        print("Predicted")
        visualize(image, torch.argmax(pred, 0))
        
        accuracy = (torch.argmax(pred, 0) == target).float().mean()
        
        macroF1 = compute_macro_f1(torch.argmax(pred, 0), target, 4)
        
        iou_list = compute_iou(torch.argmax(pred, 0), target, 4)
        
        print(f"Test Accuracy: {accuracy:.4f}, "
              f"Test MacroF1: {macroF1:.4f}, "
              f"Test mean IoU: {mean(iou_list)}")
    
        break
# Out:
# Actual
# Predicted
# Test Accuracy: 0.2128, Test MacroF1: 0.1492, Test mean IoU: 0.08650412808158615

# %%
test_acc = []
test_mF1 = []
test_IoU = []
for sample in test_dl:
    # print(sample["image"].shape)
    # print(sample["mask"].shape)
    target = sample["mask"][0, :, :]
    pred = unet_model(sample["image"].cuda()).cpu()[0]
    
    accuracy = (torch.argmax(pred, 0) == target).float().mean()
    test_acc.append(accuracy.tolist())
    macroF1 = compute_macro_f1(torch.argmax(pred, 0), target, 4)
    test_mF1.append(macroF1)
    iou_list = compute_iou(torch.argmax(pred, 0), target, 4)
    test_IoU.append(mean(iou_list))

print(f"Average Test Accuracy: {mean(test_acc):.4f}\n"
      f"Average Test MacroF1: {mean(test_mF1):.4f}\n"
      f"Average Test mean IoU: {mean(test_IoU):.4f}")   

# Set the x axis label of the current axis.
plt.xlabel('Bacth No.')
# Set the y axis label of the current axis.
plt.ylabel('Metric')
# Set a title 
plt.title('Test Data set evaluation batch-wise')
# Display the figure.
plt.plot(range(1, len(test_acc)+1), test_acc, color='blue', linewidth = 1,  label = 'Accruacy')
plt.plot(range(1, len(test_mF1)+1), test_mF1, color='yellow', linewidth = 1,  label = 'Macro F1')
plt.plot(range(1, len(test_IoU)+1), test_IoU, color='red', linewidth = 1,  label = 'IoU')
# show a legend on the plot
plt.legend()
plt.show()
# Out:
# Average Test Accuracy: 0.5805
# Average Test MacroF1: 0.3905
# Average Test mean IoU: 0.2987

# %%
#Additional Info when using cuda
if DEVICE.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# NVIDIA GeForce RTX 2060 SUPER
# Memory Usage:
# Allocated: 0.1 GB
# Cached:    3.1 GB
